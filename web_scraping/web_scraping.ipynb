# %%
import requests # pip install requests
from lxml import html # pip install lxml

# %% [markdown]
# # Extraer idiomas de la página de wikipedia

# %% [markdown]
# OBJETIVOS:
#   - Extraer los idiomas de la pagina principal de WIKIPEDIA
#   - Aprender a utilizar requests para hacer requerimientos
#   - Aprender a utilizar lxml para parsear el arbol HTML
# CREADO POR: [LEONARDO KUFFO](https://github.com/lkuffo/web-scraping/blob/master/NIVEL%201/1_wikipedia.py)
#
# ULTIMA VEZ EDITADO: 12 ABRIL 2020

# %%
# USER AGENT PARA PROTEGERNOS DE BANEOS
headers = {
    "user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/71.0.3578.80 Chrome/71.0.3578.80 Safari/537.36",
}

# URL SEMILLA
url = 'https://www.wikipedia.org/'

# REQUERIMIENTO AL SERVIDOR
respuesta = requests.get(url, headers=headers)

# PARSEO DEL ARBOL HTML QUE RECIBO COMO RESPUESTA CON LXML
parser = html.fromstring(respuesta.text)

# EXTRACCION DE IDIOMA INGLES
ingles = parser.get_element_by_id("js-link-box-en")
print (ingles.text_content())

# EXTRACCION SOLO DEL TEXTO QUE DICE INGLES
ingles = parser.xpath("//a[@id='js-link-box-en']/strong/text()")
print(ingles[0])

# EXTRACCION DE TODOS LOS IDIOMAS POR CLASE
idiomas = parser.find_class('central-featured-lang')
for idioma in idiomas:
      print("--> ",idioma.text_content())

# EXTRACCION DE TODOS LOS IDIOMAS POR XPATH
idiomas = parser.xpath("//div[contains(@class,'central-featured-lang')]//strong/text()")
for idioma in idiomas:
      print(idioma)
# Out:
# English
# 6 121 000+ articles
#
# English
# -->
#
# English
# 6 121 000+ articles
#
#
# -->
#
# æ¥æ¬èª
# 1 216 000+ è¨äº
#
#
# -->
#
# EspaÃ±ol
# 1 611 000+ artÃ­culos
#
#
# -->
#
# Deutsch
# 2 455 000+ Artikel
#
#
# -->
#
# Ð ÑÑÑÐºÐ¸Ð¹
# 1 642 000+ ÑÑÐ°ÑÐµÐ¹
#
#
# -->
#
# FranÃ§ais
# 2 234 000+ articles
#
#
# -->
#
# Italiano
# 1 622 000+ voci
#
#
# -->
#
# ä¸­æ
# 1 128 000+ æ¢ç®
#
#
# -->
#
# PortuguÃªs
# 1 038 000+ artigos
#
#
# -->
#
# Polski
# 1 419 000+ haseÅ
#
#
# English
# æ¥æ¬èª
# EspaÃ±ol
# Deutsch
# Ð ÑÑÑÐºÐ¸Ð¹
# FranÃ§ais
# Italiano
# ä¸­æ
# PortuguÃªs
# Polski

# %% [markdown]
# # Preguntas de stack overflow
#
# OBJETIVO:
#   - Extraer las preguntas de la pagina principal de Stackoverflow
#   - Aprender a utilizar Beautiful Soup para parsear el arbol HTML
#
# CREADO POR: [LEONARDO KUFFO](https://github.com/lkuffo/web-scraping/blob/master/NIVEL%201/1_wikipedia.py)
#
# ULTIMA VEZ EDITADO: 12 ABRIL 2020

# %%
import requests
from bs4 import BeautifulSoup # pip install beautifulsoup4

# USER AGENT PARA PROTEGERNOS DE BANEOS
headers = {
    "user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/71.0.3578.80 Chrome/71.0.3578.80 Safari/537.36"
}

# URL SEMILLA
url = 'https://stackoverflow.com/questions'

# REQUERIMIENTO AL SERVIDOR
respuesta = requests.get(url, headers=headers)

# PARSEO DEL ARBOL CON BEAUTIFUL SOUP
soup = BeautifulSoup(respuesta.text)
contenedor_de_preguntas = soup.find(id="questions") # ENCONTRAR UN ELEMENTO POR ID
lista_de_preguntas = contenedor_de_preguntas.find_all('div', class_="question-summary") # ENCONTRAR VARIOS ELEMENTOS POR TAG Y POR CLASE

# %%
for pregunta in lista_de_preguntas: # ITERAR ELEMENTO POR ELEMENTO

  # METODO #1: METODO TRADICIONAL
  texto_pregunta = pregunta.find('h3').text # DENTRO DE CADA ELEMENTO ITERADO ENCONTRAR UN TAG
  descripcion_pregunta = pregunta.find(class_='excerpt').text # ENCONTRAR POR CLASE
  descripcion_pregunta = descripcion_pregunta.replace('\n', '').replace('\r', '') # LIMPIEZA DE TEXTO
  print (texto_pregunta)
  print (descripcion_pregunta)
  print ()
# Out:
# How to open and save array in MongoDB with NodeJS
#             I have a problem with my aggregation framework inside a MongoDB. This problem is caused that I save data in MongoDB in Array.I want that, when the data is saved it's not in array. Explanation on ...
#
# Block windows portable devices(WPD) without using Group Policy or registry c++?
#             I want to block the windows portable devices especially android/ios smartphones to prevent any kind of data transfer from computer to android/ios.I know I can use the Group Policy or registry to ...
#
# selector WebDriverWait work, WebDriver not work?
#             I haveusing IWebDriver driver = new FirefoxDriver();WebDriverWait webDriverWait = new WebDriverWait(driver, TimeSpan.FromSeconds(10));IWebElement webElement1 = webDriverWait.Until(...
#
# How to fix camera not turning(Black Screen) on when using Agora SDK?
#             am using latest Agora SDK for voice/video callIn voice call i cant hear recivers voice and in video calli can't see any video neither the reciver can see my video(I have set permissions and they ...
#
# Custom Plugin to JCE using TinyMCE Dialog
#             Im using joomla and JCE Editor in my articlesim trying to build a plugin with tinyMCE for a button on the editor that will open a dialog boxi used this code :(function () {    tinymce....
#
# How to get CaffeineCacheManager from application context in SpringBoot?
#             I want to use custom WrappingCacheManager as a decorator for CaffeineCacheManager.Currently configuration is created imperatively with Caffeine.newBuilder()..., and I want to replace it with a ...
#
# I have multiple files of `.zcompdump` , why do I have multiple files of these?
#             I have multiple files of .zcomdump..rw-r--r--   47k myuser 13 Jul 10:02  .zcompdump.rw-r--r--   47k myuser 14 Jul 16:52  .zcompdump-MacBook Pro (2)-5.7.1.rw-r--r--   47k myuser  4 Jun  9:32  ....
#
# Vuetify: DataTable with Array of Strings
#             This seems like another simple question, but is there a possibility to create a Vuetify DataTable with an Array of Strings?I don't wanna use a simple DataTable, because I need the selection.I might ...
#
# Getting data for multiple products using a single scraper
#             I have the link https://www.1800wheelchair.com/category/369/transport-wheelchairs/ from which I want to extract table data for all products (specifications). I could write the code for a single ...
#
# Sparkcontext stopped inside listener
#             I have the following listener where I create a dataset and am trying to save it to MYSQL. I want this save to happen at end of spark program, so I am using a listener for that.The listener is...
#
# Entity Framework 3.1 One-To-Many Insert data
#             I have Offer and OfferLocation. One offer can have many offer location. While saving offer I also want to save offer locations into offer location table, but I get an error saying:"Microsoft....
#
# How to get input to reflect existing html elements
#             I am creating a program, where the user is capable of modifying the Css of elements directly. Say, the color and font of a header.This is done the following way: The user clicks on an existing ...
#
# How to inject services into other services in Loopback JS?
#             New to Loopback framework.I come from Angular and Java (Spring Framework), where a pattern like this is quite common.How would I go about doing something similar in Loopback?@bind({ scope: ...
#
# Cucumber HTML report - How can I get the timestamp in each scenario title?
#             I've tried adding scenarioTimestamp: true in the onComplete: () function in the config file. However, after the tests are executed, the timestamp is not showing up. Do I need to update the cucumber-...
#
# Quick question, why is my exponents capped?
#             public static void main(String[] args){int res = (int)Math.pow(2017, 202);System.out.println(res);}This outputs 2147483647Which is obviously wrong and if i type in other exponents the output ...

# %%
for pregunta in lista_de_preguntas: # ITERAR ELEMENTO POR ELEMENTO
  # METODO #2: APROVECHANDO EL PODER COMPLETO DE BEAUTIFUL SOUP
  contenedor_pregunta = pregunta.find('h3')
  texto_pregunta = contenedor_pregunta.text
  descripcion_pregunta = contenedor_pregunta.find_next_sibling('div') # TRAVERSANDO EL ARBOL DE UNA MENERA DIFERENTE
  texto_descripcion_pregunta = descripcion_pregunta.text

  texto_descripcion_pregunta = texto_descripcion_pregunta.replace('\n', '').replace('\t', '')
  print (texto_pregunta)
  print (texto_descripcion_pregunta)
  print ()
# Out:
# How to open and save array in MongoDB with NodeJS
#             I have a problem with my aggregation framework inside a MongoDB. This problem is caused that I save data in MongoDB in Array.I want that, when the data is saved it's not in array. Explanation on ...
#
# Block windows portable devices(WPD) without using Group Policy or registry c++?
#             I want to block the windows portable devices especially android/ios smartphones to prevent any kind of data transfer from computer to android/ios.I know I can use the Group Policy or registry to ...
#
# selector WebDriverWait work, WebDriver not work?
#             I haveusing IWebDriver driver = new FirefoxDriver();WebDriverWait webDriverWait = new WebDriverWait(driver, TimeSpan.FromSeconds(10));IWebElement webElement1 = webDriverWait.Until(...
#
# How to fix camera not turning(Black Screen) on when using Agora SDK?
#             am using latest Agora SDK for voice/video callIn voice call i cant hear recivers voice and in video calli can't see any video neither the reciver can see my video(I have set permissions and they ...
#
# Custom Plugin to JCE using TinyMCE Dialog
#             Im using joomla and JCE Editor in my articlesim trying to build a plugin with tinyMCE for a button on the editor that will open a dialog boxi used this code :(function () {    tinymce....
#
# How to get CaffeineCacheManager from application context in SpringBoot?
#             I want to use custom WrappingCacheManager as a decorator for CaffeineCacheManager.Currently configuration is created imperatively with Caffeine.newBuilder()..., and I want to replace it with a ...
#
# I have multiple files of `.zcompdump` , why do I have multiple files of these?
#             I have multiple files of .zcomdump..rw-r--r--   47k myuser 13 Jul 10:02  .zcompdump.rw-r--r--   47k myuser 14 Jul 16:52  .zcompdump-MacBook Pro (2)-5.7.1.rw-r--r--   47k myuser  4 Jun  9:32  ....
#
# Vuetify: DataTable with Array of Strings
#             This seems like another simple question, but is there a possibility to create a Vuetify DataTable with an Array of Strings?I don't wanna use a simple DataTable, because I need the selection.I might ...
#
# Getting data for multiple products using a single scraper
#             I have the link https://www.1800wheelchair.com/category/369/transport-wheelchairs/ from which I want to extract table data for all products (specifications). I could write the code for a single ...
#
# Sparkcontext stopped inside listener
#             I have the following listener where I create a dataset and am trying to save it to MYSQL. I want this save to happen at end of spark program, so I am using a listener for that.The listener is...
#
# Entity Framework 3.1 One-To-Many Insert data
#             I have Offer and OfferLocation. One offer can have many offer location. While saving offer I also want to save offer locations into offer location table, but I get an error saying:"Microsoft....
#
# How to get input to reflect existing html elements
#             I am creating a program, where the user is capable of modifying the Css of elements directly. Say, the color and font of a header.This is done the following way: The user clicks on an existing ...
#
# How to inject services into other services in Loopback JS?
#             New to Loopback framework.I come from Angular and Java (Spring Framework), where a pattern like this is quite common.How would I go about doing something similar in Loopback?@bind({ scope: ...
#
# Cucumber HTML report - How can I get the timestamp in each scenario title?
#             I've tried adding scenarioTimestamp: true in the onComplete: () function in the config file. However, after the tests are executed, the timestamp is not showing up. Do I need to update the cucumber-...
#
# Quick question, why is my exponents capped?
#             public static void main(String[] args){int res = (int)Math.pow(2017, 202);System.out.println(res);}This outputs 2147483647Which is obviously wrong and if i type in other exponents the output ...
